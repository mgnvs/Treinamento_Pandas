# %% [markdown]
# nome: João Pedro Assis Santos
# <br>
# rm: 98101

# %% [markdown]
# Sugestão: Colocar a página do Cookbook lado a lado com este notebook para realizar as operações.

# %%
import numpy as np
import pandas as pd

# %%
pd.show_versions()
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 0f437949513225922d851e9581723d82120684a6
# python           : 3.10.12.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 6.1.58+
# Version          : #1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 2.0.3
# numpy            : 1.25.2
# pytz             : 2023.4
# dateutil         : 2.8.2
# setuptools       : 67.7.2
# pip              : 23.1.2
# Cython           : 3.0.10
# pytest           : 7.4.4
# hypothesis       : None
# sphinx           : 5.0.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.4
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : 2.9.9
# jinja2           : 3.1.3
# IPython          : 7.34.0
# pandas_datareader: 0.10.0
# bs4              : 4.12.3
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : 2023.6.0
# gcsfs            : 2023.6.0
# matplotlib       : 3.7.1
# numba            : 0.58.1
# numexpr          : 2.10.0
# odfpy            : None
# openpyxl         : 3.1.2
# pandas_gbq       : 0.19.2
# pyarrow          : 14.0.2
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.11.4
# snappy           : None
# sqlalchemy       : 2.0.29
# tables           : 3.8.0
# tabulate         : 0.9.0
# xarray           : 2023.7.0
# xlrd             : 2.0.1
# zstandard        : None
# tzdata           : 2024.1
# qtpy             : None
# pyqt5            : None

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.597263  0.226879  0.122435 -1.536290
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-03  0.597058  0.432603  1.122803  0.345162
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054
# 2013-01-06  0.578390 -1.977657 -0.055773  0.024298

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.597263  0.226879  0.122435 -1.536290
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-03  0.597058  0.432603  1.122803  0.345162
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054
# 2013-01-06  0.578390 -1.977657 -0.055773  0.024298

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.597263  ,  0.22687926,  0.12243482, -1.53629033],
#        [-2.3687025 , -0.88849651, -0.70138279, -1.19036537],
#        [ 0.59705822,  0.43260278,  1.12280271,  0.34516179],
#        [ 0.33492679, -0.28327065, -1.61494321, -2.53566899],
#        [ 2.27520865, -1.48410132, -1.43712758,  0.43805385],
#        [ 0.57839005, -1.97765681, -0.05577277,  0.02429803]])

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.335691 -0.662341 -0.427331 -0.742469
# std    1.501407  0.958102  1.034256  1.200903
# min   -2.368703 -1.977657 -1.614943 -2.535669
# 25%    0.395793 -1.335200 -1.253191 -1.449809
# 50%    0.587724 -0.585884 -0.378578 -0.583034
# 75%    0.597212  0.099342  0.077883  0.264946
# max    2.275209  0.432603  1.122803  0.438054

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.597263   -2.368703    0.597058    0.334927    2.275209    0.578390
# B    0.226879   -0.888497    0.432603   -0.283271   -1.484101   -1.977657
# C    0.122435   -0.701383    1.122803   -1.614943   -1.437128   -0.055773
# D   -1.536290   -1.190365    0.345162   -2.535669    0.438054    0.024298

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.536290  0.122435  0.226879  0.597263
# 2013-01-02 -1.190365 -0.701383 -0.888497 -2.368703
# 2013-01-03  0.345162  1.122803  0.432603  0.597058
# 2013-01-04 -2.535669 -1.614943 -0.283271  0.334927
# 2013-01-05  0.438054 -1.437128 -1.484101  2.275209
# 2013-01-06  0.024298 -0.055773 -1.977657  0.578390

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-06  0.578390 -1.977657 -0.055773  0.024298
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669
# 2013-01-01  0.597263  0.226879  0.122435 -1.536290
# 2013-01-03  0.597058  0.432603  1.122803  0.345162

# %%
df["A"]
# Out:
# 2013-01-01    0.597263
# 2013-01-02   -2.368703
# 2013-01-03    0.597058
# 2013-01-04    0.334927
# 2013-01-05    2.275209
# 2013-01-06    0.578390
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.597263  0.226879  0.122435 -1.536290
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-03  0.597058  0.432603  1.122803  0.345162

# %%
df[1:-1]
# Out:
#                    A         B         C         D
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-03  0.597058  0.432603  1.122803  0.345162
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.597263  0.226879  0.122435 -1.536290
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-03  0.597058  0.432603  1.122803  0.345162
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054
# 2013-01-06  0.578390 -1.977657 -0.055773  0.024298

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-03  0.597058  0.432603  1.122803  0.345162
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669

# %%
df.loc[dates[0]]
# Out:
# A    0.597263
# B    0.226879
# C    0.122435
# D   -1.536290
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.597263  0.226879
# 2013-01-02 -2.368703 -0.888497
# 2013-01-03  0.597058  0.432603
# 2013-01-04  0.334927 -0.283271
# 2013-01-05  2.275209 -1.484101
# 2013-01-06  0.578390 -1.977657

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -2.368703 -0.888497
# 2013-01-03  0.597058  0.432603
# 2013-01-04  0.334927 -0.283271

# %%
df.loc[dates[0], "A"]
# Out:
# 0.597263000665577

# %%
df.at[dates[0], "A"]
# Out:
# 0.597263000665577

# %%
df.iloc[3]
# Out:
# A    0.334927
# B   -0.283271
# C   -1.614943
# D   -2.535669
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.334927 -0.283271
# 2013-01-05  2.275209 -1.484101

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.334927 -0.283271
# 2013-01-05  2.275209 -1.484101

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365
# 2013-01-03  0.597058  0.432603  1.122803  0.345162

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.226879  0.122435
# 2013-01-02 -0.888497 -0.701383
# 2013-01-03  0.432603  1.122803
# 2013-01-04 -0.283271 -1.614943
# 2013-01-05 -1.484101 -1.437128
# 2013-01-06 -1.977657 -0.055773

# %%
df.iloc[1, 1]
# Out:
# -0.8884965093534912

# %%
df.iat[1, 1]
# Out:
# -0.8884965093534912

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.597263  0.226879  0.122435 -1.536290
# 2013-01-03  0.597058  0.432603  1.122803  0.345162
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054
# 2013-01-06  0.578390 -1.977657 -0.055773  0.024298

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.597263  0.226879  0.122435       NaN
# 2013-01-02       NaN       NaN       NaN       NaN
# 2013-01-03  0.597058  0.432603  1.122803  0.345162
# 2013-01-04  0.334927       NaN       NaN       NaN
# 2013-01-05  2.275209       NaN       NaN  0.438054
# 2013-01-06  0.578390       NaN       NaN  0.024298

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.597263  0.226879  0.122435 -1.536290    one
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365    one
# 2013-01-03  0.597058  0.432603  1.122803  0.345162    two
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669  three
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054   four
# 2013-01-06  0.578390 -1.977657 -0.055773  0.024298  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.597058  0.432603  1.122803  0.345162   two
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.226879  0.122435 -1.536290  NaN
# 2013-01-02 -2.368703 -0.888497 -0.701383 -1.190365  1.0
# 2013-01-03  0.597058  0.432603  1.122803  0.345162  2.0
# 2013-01-04  0.334927 -0.283271 -1.614943 -2.535669  3.0
# 2013-01-05  2.275209 -1.484101 -1.437128  0.438054  4.0
# 2013-01-06  0.578390 -1.977657 -0.055773  0.024298  5.0

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  0.122435  5.0  NaN
# 2013-01-02 -2.368703 -0.888497 -0.701383  5.0  1.0
# 2013-01-03  0.597058  0.432603  1.122803  5.0  2.0
# 2013-01-04  0.334927 -0.283271 -1.614943  5.0  3.0
# 2013-01-05  2.275209 -1.484101 -1.437128  5.0  4.0
# 2013-01-06  0.578390 -1.977657 -0.055773  5.0  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.122435 -5.0  NaN
# 2013-01-02 -2.368703 -0.888497 -0.701383 -5.0 -1.0
# 2013-01-03 -0.597058 -0.432603 -1.122803 -5.0 -2.0
# 2013-01-04 -0.334927 -0.283271 -1.614943 -5.0 -3.0
# 2013-01-05 -2.275209 -1.484101 -1.437128 -5.0 -4.0
# 2013-01-06 -0.578390 -1.977657 -0.055773 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.122435  5.0  NaN  1.0
# 2013-01-02 -2.368703 -0.888497 -0.701383  5.0  1.0  1.0
# 2013-01-03  0.597058  0.432603  1.122803  5.0  2.0  NaN
# 2013-01-04  0.334927 -0.283271 -1.614943  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02 -2.368703 -0.888497 -0.701383  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.122435  5.0  5.0  1.0
# 2013-01-02 -2.368703 -0.888497 -0.701383  5.0  1.0  1.0
# 2013-01-03  0.597058  0.432603  1.122803  5.0  2.0  5.0
# 2013-01-04  0.334927 -0.283271 -1.614943  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.236147
# B   -0.700154
# C   -0.427331
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.280609
# 2013-01-02    0.408284
# 2013-01-03    1.830493
# 2013-01-04    1.287343
# 2013-01-05    1.670796
# 2013-01-06    1.708992
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.402942 -0.567397  0.122803  4.0  1.0
# 2013-01-04 -2.665073 -3.283271 -4.614943  2.0  0.0
# 2013-01-05 -2.724791 -6.484101 -6.437128  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A     1.322422
# B    -3.920861
# C    -2.393056
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000   12.390404  506.0    NaN
# 2013-01-02 -239.712693  -89.915847  -70.979938  506.0  101.2
# 2013-01-03   60.422292   43.779401  113.627634  506.0  202.4
# 2013-01-04   33.894591  -28.666990 -163.432253  506.0  303.6
# 2013-01-05  230.251115 -150.191054 -145.437311  506.0  404.8
# 2013-01-06   58.533073 -200.138870   -5.644204  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    1
# 1    5
# 2    3
# 3    3
# 4    6
# 5    2
# 6    2
# 7    3
# 8    6
# 9    4
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    3
# 6    2
# 2    2
# 1    1
# 5    1
# 4    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  1.671022 -1.247693  0.372576  1.218005
# 1  0.696145 -0.625998 -0.601728  0.167733
# 2  1.067098  0.982953 -0.577133 -1.116230
# 3  0.554626 -0.014307 -0.338511 -0.747452
# 4 -1.010780 -0.170953  1.615423  0.046586
# 5  0.684203  0.733657  0.136593 -0.407843
# 6  0.471126  0.280343 -0.978672 -0.984494
# 7 -1.154281  0.417981 -0.248197 -0.283948
# 8 -0.035551 -1.693246  0.778662 -0.878492
# 9 -2.081278  1.386500  0.623549 -0.495247

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.671022 -1.247693  0.372576  1.218005
# 1  0.696145 -0.625998 -0.601728  0.167733
# 2  1.067098  0.982953 -0.577133 -1.116230
# 3  0.554626 -0.014307 -0.338511 -0.747452
# 4 -1.010780 -0.170953  1.615423  0.046586
# 5  0.684203  0.733657  0.136593 -0.407843
# 6  0.471126  0.280343 -0.978672 -0.984494
# 7 -1.154281  0.417981 -0.248197 -0.283948
# 8 -0.035551 -1.693246  0.778662 -0.878492
# 9 -2.081278  1.386500  0.623549 -0.495247

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one  0.667113 -0.711695
# 1  bar    one  0.247945 -1.093292
# 2  foo    two  1.569323  0.854592
# 3  bar  three  1.295373  0.118018
# 4  foo    two -0.831918  1.251751
# 5  bar    two  1.203644  1.489516
# 6  foo    one  0.470622  1.161869
# 7  foo  three  0.426870 -0.384070

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  2.746962  0.514243
# foo  2.302009  2.172447

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.247945 -1.093292
#     three  1.295373  0.118018
#     two    1.203644  1.489516
# foo one    1.137735  0.450174
#     three  0.426870 -0.384070
#     two    0.737405  2.106342

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -0.369764 -0.898681
#       two     1.195033 -0.354982
# baz   one    -0.767005  0.463078
#       two     2.179083  0.987913

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.369764
#                B   -0.898681
#        two     A    1.195033
#                B   -0.354982
# baz    one     A   -0.767005
#                B    0.463078
#        two     A    2.179083
#                B    0.987913
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.369764 -0.898681
#       two     1.195033 -0.354982
# baz   one    -0.767005  0.463078
#       two     2.179083  0.987913

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.369764  1.195033
#       B -0.898681 -0.354982
# baz   A -0.767005  2.179083
#       B  0.463078  0.987913

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.369764 -0.767005
#        B -0.898681  0.463078
# two    A  1.195033  2.179083
#        B -0.354982  0.987913

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.786978  0.675734
# 1     one  B  foo -0.022770 -0.395294
# 2     two  C  foo  0.100517 -0.891989
# 3   three  A  bar -1.962932 -0.039378
# 4     one  B  bar  0.021818 -0.443438
# 5     one  C  bar  0.611351  2.033161
# 6     two  A  foo  0.039590  0.395360
# 7   three  B  foo  0.784981  0.128129
# 8     one  C  foo -0.190991  0.483833
# 9     one  A  bar -0.212829 -0.910766
# 10    two  B  bar -0.201200 -0.189630
# 11  three  C  bar -0.195473  0.978331

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.212829 -0.786978
#       B  0.021818 -0.022770
#       C  0.611351 -0.190991
# three A -1.962932       NaN
#       B       NaN  0.784981
#       C -0.195473       NaN
# two   A       NaN  0.039590
#       B -0.201200       NaN
#       C       NaN  0.100517

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    23696
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06   -0.480980
# 2012-03-07    0.252152
# 2012-03-08    0.014933
# 2012-03-09   -1.938682
# 2012-03-10    1.337856
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.480980
# 2012-03-07 00:00:00+00:00    0.252152
# 2012-03-08 00:00:00+00:00    0.014933
# 2012-03-09 00:00:00+00:00   -1.938682
# 2012-03-10 00:00:00+00:00    1.337856
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.480980
# 2012-03-06 19:00:00-05:00    0.252152
# 2012-03-07 19:00:00-05:00    0.014933
# 2012-03-08 19:00:00-05:00   -1.938682
# 2012-03-09 19:00:00-05:00    1.337856
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts.cumsum()
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc='best');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-18da75158ce1> in <cell line: 1>()
# ----> 1 df = pd.DataFrame(
#       2     np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
#       3 )
#       4 df = df.cumsum()
#       5 plt.figure();
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     756                 )
#     757             else:
# --> 758                 mgr = ndarray_to_mgr(
#     759                     data,
#     760                     index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     335     )
#     336
# --> 337     _check_values_indices_shape_match(values, index, columns)
#     338
#     339     if typ == "array":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     406         passed = values.shape
#     407         implied = (len(index), len(columns))
# --> 408         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     409
#     410
#
# ValueError: Shape of passed values is (1000, 4), indices imply (5, 4)

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv("foo.csv")

# %%
df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  1  4  1  3  1
# 1  1  2  3  0  2
# 2  2  4  4  4  3
# 3  2  1  2  2  1
# 4  1  1  1  4  3
# 5  0  1  0  4  4
# 6  4  1  3  1  2
# 7  3  1  4  3  3
# 8  4  4  1  1  4
# 9  0  3  0  3  2

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  4  1  3  1
# 1           1  1  2  3  0  2
# 2           2  2  4  4  4  3
# 3           3  2  1  2  2  1
# 4           4  1  1  1  4  3
# 5           5  0  1  0  4  4
# 6           6  4  1  3  1  2
# 7           7  3  1  4  3  3
# 8           8  4  4  1  1  4
# 9           9  0  3  0  3  2

# %%
if pd.Series([False, True, False]):
  print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-06fa23a4b3e2> in <cell line: 1>()
# ----> 1 if pd.Series([False, True, False]):
#       2   print("I was true")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
